# %%
from fastai.basics import *
from fastai.vision import models
from fastai.vision.all import *
from fastai.metrics import *
from fastai.data.all import *
from fastai.callback import *

# SemTorch
from semtorch import get_segmentation_learner
import segmentation_models_pytorch as smp

from pathlib import Path
import random
# Out:
# /home/jonathan/.virtualenvs/segmentation/lib/python3.6/site-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %%
import torch
torch.cuda.set_device(0)

# %%
# %matplotlib inline
import numpy as np

# %% [markdown]
# Function por stablishing the seed for reproducibility

# %%
number_of_the_seed = 2020

random.seed(number_of_the_seed)
set_seed(number_of_the_seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
path = Path("dataset/")
path_images = path/"Images"
path_labels = path/"Labels"

test_name = "test"

# %% [markdown]
# Obtaining the label associated with an image, in the case of segmentation it is a mask

# %%
get_y_fn = lambda x: Path(str(x).replace("Images","Labels").replace("color","gt").replace(".jpg",".png"))

# %% [markdown]
# Aux function for splitting between training and testing

# %%
def ParentSplitter(x):
    return Path(x).parent.name==test_name

# %% [markdown]
# Loading the codes of the different classes. All the datasets have the same codes.

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str)

# %%
def msa(input, target):
    target = target.squeeze(1)
    mask = target != -1
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

def background(input, target):
    target = target.squeeze(1)
    mask = target != 0
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

def leaves(input, target):
    target = target.squeeze(1)
    mask = target != 1
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

def wood(input, target):
    target = target.squeeze(1)
    mask = target != 2
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

def pole(input, target):
    target = target.squeeze(1)
    mask = target != 3
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

def grape(input, target):
    target = target.squeeze(1)
    mask = target != 4
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %% [markdown]
# Early Stopping parameters

# %%
monitor_training="valid_loss"
comp_training=np.less

monitor_evaluating="dice"
comp_evaluating=np.greater

patience=3

# %%
from albumentations import (
    Compose,
    OneOf,
    ElasticTransform,
    GridDistortion, 
    OpticalDistortion,
    Flip,
    Rotate,
    Transpose,
    CLAHE,
    ShiftScaleRotate
)

# %%
class SegmentationAlbumentationsTransform(ItemTransform):
    split_idx = 0
    def __init__(self, aug): 
        self.aug = aug
    def encodes(self, x):
        img,mask = x
        aug = self.aug(image=np.array(img), mask=np.array(mask))
        return PILImage.create(aug["image"]), PILMask.create(aug["mask"])
    
transformPipeline=Compose([
                        Flip(p=0.5),
                        Transpose(p=0.5),
                        Rotate(p=0.40,limit=10),GridDistortion()
                    ],p=1)

transformPipeline=SegmentationAlbumentationsTransform(transformPipeline)

# %%
class TargetMaskConvertTransform(ItemTransform):
    def __init__(self): 
        pass
    def encodes(self, x):
        img,mask = x
        
        #Convert to array
        mask = np.array(mask)
        
        # Change 255 for 4
        mask[mask==255]=4
        mask[mask==150]=1
        mask[mask==76]=3
        mask[mask==74]=3
        mask[mask==29]=2
        mask[mask==25]=2
        
        # Back to PILMask
        mask = PILMask.create(mask)
        return img, mask

# %%
path_manual_img = path_images/'train'
path_manual_lbl = path_labels/'train'

# %%
fnames_manual = get_image_files(path_manual_img)
lbl_names_manual = get_image_files(path_manual_lbl)

# open and show image
img_f = fnames_manual[10]
print(img_f)
img = PILImage.create(img_f)
img.show(figsize=(5, 5))
# Out:
# dataset/Images/train/color_159.jpg
# <AxesSubplot:>

# %%
print(get_y_fn(img_f))
# Out:
# dataset/Labels/train/gt_159.png

# %%
mask = PILMask.create(get_y_fn(img_f))
mask.show(figsize=(5, 5), alpha=1)
# Out:
# <AxesSubplot:>

# %%
np.unique(np.array(mask))
# Out:
# array([  0,  29,  76, 150, 255], dtype=uint8)

# %%
bs = 4

# %%
codes
# Out:
# array(['Background', 'Leaves', 'Wood', 'Pole', 'Grape'], dtype='<U10')

# %%
def my_get_items(folders,path):
    return (get_image_files(path))

# %%
manual = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=partial(get_image_files,folders=['train','trainSemi','test']),
                   get_y=get_y_fn,
                   splitter=FuncSplitter(ParentSplitter),
                   item_tfms=[Resize((480,640)), TargetMaskConvertTransform(), transformPipeline],
                   batch_tfms=Normalize.from_stats(*imagenet_stats)
                  )
#manual.summary(path_images)
dls = manual.dataloaders(path_images,bs=bs)
#dls.show_batch(vmin=0,vmax=1,figsize=(12, 9))

# %%
#x,mask=dls.one_batch()

# %% [markdown]
# # Deeplab

# %%
model = smp.MAnet(
    encoder_name="timm-efficientnet-b3",        # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
    encoder_weights="imagenet",     # use `imagenet` pre-trained weights for encoder initialization
    in_channels=3,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
    classes=5,                      # model output channels (number of classes in your dataset)
)

# %%
learn = Learner(dls,model,metrics=[background,leaves,pole,grape,wood,msa]).to_fp16()

# %%
learn.lr_find() # find learning rate
learn.recorder # plot learning rate graph
# Out:
# Recorder

# %%
fname="deeplab-before-unfreeze"

callbacksFitBeforeUnfreeze = [
    ShowGraphCallback(),
    EarlyStoppingCallback(monitor=monitor_training,comp=comp_training, patience=patience),
    SaveModelCallback(monitor=monitor_training,comp=comp_training,every_epoch=False,fname=fname)  
]
learn.fit_one_cycle(20, slice(1e-4,1e-3),cbs=callbacksFitBeforeUnfreeze)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>background</th>
#       <th>leaves</th>
#       <th>pole</th>
#       <th>grape</th>
#       <th>wood</th>
#       <th>msa</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.711179</td>
#       <td>1.688693</td>
#       <td>0.149095</td>
#       <td>0.299693</td>
#       <td>0.226742</td>
#       <td>0.228291</td>
#       <td>0.230947</td>
#       <td>0.229431</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.519841</td>
#       <td>1.305944</td>
#       <td>0.480597</td>
#       <td>0.483512</td>
#       <td>0.505317</td>
#       <td>0.504359</td>
#       <td>0.506578</td>
#       <td>0.500177</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.265691</td>
#       <td>1.051045</td>
#       <td>0.831545</td>
#       <td>0.498669</td>
#       <td>0.689865</td>
#       <td>0.688693</td>
#       <td>0.691667</td>
#       <td>0.681016</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.010018</td>
#       <td>0.619443</td>
#       <td>0.810051</td>
#       <td>0.764102</td>
#       <td>0.833732</td>
#       <td>0.831913</td>
#       <td>0.837388</td>
#       <td>0.822227</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.824266</td>
#       <td>0.530101</td>
#       <td>0.809710</td>
#       <td>0.784686</td>
#       <td>0.845540</td>
#       <td>0.843633</td>
#       <td>0.849269</td>
#       <td>0.833810</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.693345</td>
#       <td>0.519686</td>
#       <td>0.810127</td>
#       <td>0.770613</td>
#       <td>0.834003</td>
#       <td>0.833085</td>
#       <td>0.836758</td>
#       <td>0.823379</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.601413</td>
#       <td>0.533453</td>
#       <td>0.860357</td>
#       <td>0.717103</td>
#       <td>0.824893</td>
#       <td>0.823947</td>
#       <td>0.824580</td>
#       <td>0.814354</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.535056</td>
#       <td>0.498170</td>
#       <td>0.840679</td>
#       <td>0.771446</td>
#       <td>0.839933</td>
#       <td>0.840767</td>
#       <td>0.839233</td>
#       <td>0.830941</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.483242</td>
#       <td>0.535157</td>
#       <td>0.875826</td>
#       <td>0.705363</td>
#       <td>0.819237</td>
#       <td>0.819478</td>
#       <td>0.815729</td>
#       <td>0.809932</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.438770</td>
#       <td>0.485284</td>
#       <td>0.878360</td>
#       <td>0.720170</td>
#       <td>0.829724</td>
#       <td>0.830542</td>
#       <td>0.829270</td>
#       <td>0.820853</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.404177</td>
#       <td>0.464878</td>
#       <td>0.874389</td>
#       <td>0.731691</td>
#       <td>0.828905</td>
#       <td>0.832421</td>
#       <td>0.831367</td>
#       <td>0.822703</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.376279</td>
#       <td>0.470935</td>
#       <td>0.877675</td>
#       <td>0.733071</td>
#       <td>0.832499</td>
#       <td>0.834612</td>
#       <td>0.831997</td>
#       <td>0.824868</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.355675</td>
#       <td>0.422374</td>
#       <td>0.866121</td>
#       <td>0.771844</td>
#       <td>0.845190</td>
#       <td>0.848607</td>
#       <td>0.845087</td>
#       <td>0.838701</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.338221</td>
#       <td>0.468095</td>
#       <td>0.884652</td>
#       <td>0.710694</td>
#       <td>0.820969</td>
#       <td>0.824559</td>
#       <td>0.823337</td>
#       <td>0.815112</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000000</td>
#       <td>0.918738</td>
#       <td>0.522624</td>
#       <td>0.521192</td>
#       <td>0.524951</td>
#       <td>0.515193</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000000</td>
#       <td>0.918738</td>
#       <td>0.522624</td>
#       <td>0.521192</td>
#       <td>0.524951</td>
#       <td>0.515193</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.6886934041976929.
# Better model found at epoch 1 with valid_loss value: 1.3059438467025757.
# Better model found at epoch 2 with valid_loss value: 1.0510450601577759.
# Better model found at epoch 3 with valid_loss value: 0.6194430589675903.
# Better model found at epoch 4 with valid_loss value: 0.5301011204719543.
# Better model found at epoch 5 with valid_loss value: 0.519686222076416.
# Better model found at epoch 7 with valid_loss value: 0.4981701672077179.
# Better model found at epoch 9 with valid_loss value: 0.48528364300727844.
# Better model found at epoch 10 with valid_loss value: 0.46487778425216675.
# Better model found at epoch 12 with valid_loss value: 0.4223739802837372.
# No improvement since epoch 12: early stopping

# %%
learn.load("deeplab-before-unfreeze")
learn.unfreeze()
#learn.lr_find() # find learning rate
#learn.recorder # plot learning rate graph
# Out:
# /home/jonathan/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")

# %%
fname="Manet-Efficient"
model = nn.DataParallel(model)

callbacksFitAfterUnfreeze = [
    ShowGraphCallback(),
    EarlyStoppingCallback(monitor=monitor_training,comp=comp_training, patience=patience),
    SaveModelCallback(monitor=monitor_training,comp=comp_training,every_epoch=False,fname=fname)  
]
learn.fit_one_cycle(20, slice(1e-7,1e-7),cbs=callbacksFitAfterUnfreeze)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>background</th>
#       <th>leaves</th>
#       <th>pole</th>
#       <th>grape</th>
#       <th>wood</th>
#       <th>msa</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.299114</td>
#       <td>0.402762</td>
#       <td>0.848711</td>
#       <td>0.798351</td>
#       <td>0.852320</td>
#       <td>0.855614</td>
#       <td>0.852565</td>
#       <td>0.845621</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.298147</td>
#       <td>0.410575</td>
#       <td>0.856029</td>
#       <td>0.787778</td>
#       <td>0.850582</td>
#       <td>0.853580</td>
#       <td>0.850615</td>
#       <td>0.843612</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.298933</td>
#       <td>0.401206</td>
#       <td>0.846369</td>
#       <td>0.801928</td>
#       <td>0.853610</td>
#       <td>0.856990</td>
#       <td>0.854585</td>
#       <td>0.846979</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.298575</td>
#       <td>0.402465</td>
#       <td>0.848503</td>
#       <td>0.797804</td>
#       <td>0.852417</td>
#       <td>0.855814</td>
#       <td>0.853526</td>
#       <td>0.845818</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.298626</td>
#       <td>0.403322</td>
#       <td>0.848099</td>
#       <td>0.799380</td>
#       <td>0.853698</td>
#       <td>0.856667</td>
#       <td>0.854093</td>
#       <td>0.846662</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.294621</td>
#       <td>0.409577</td>
#       <td>0.856945</td>
#       <td>0.784870</td>
#       <td>0.848859</td>
#       <td>0.852163</td>
#       <td>0.849224</td>
#       <td>0.842213</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.40276211500167847.
# Better model found at epoch 2 with valid_loss value: 0.4012060761451721.
# No improvement since epoch 2: early stopping

# %%
learn.load("Manet-Efficient")
# Out:
# /home/jonathan/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")

# %%
learn.validate()
# Out:
# (#7) [0.4012060761451721,0.8463689088821411,0.8019276261329651,0.8536096811294556,0.8569902777671814,0.8545852303504944,0.8469792008399963]

# %%
learn.show_results(figsize=(20,20))

# %%
aux=learn.model
aux=aux.cpu()

traced_cell=torch.jit.script(aux)
traced_cell.save("deeplab.pth")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

# HRNet

model = torch.jit.load("deeplab.pth")
model = model.cpu()
model.eval()
# Out:
# RecursiveScriptModule(
#   original_name=DeepLabV3Plus
#   (backbone): RecursiveScriptModule(
#     original_name=ResNetV1
#     (conv1): RecursiveScriptModule(original_name=Conv2d)
#     (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#     (relu): RecursiveScriptModule(original_name=ReLU)
#     (maxpool): RecursiveScriptModule(original_name=MaxPool2d)
#     (layer1): RecursiveScriptModule(
#       original_name=Sequential
#       (0): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#         (downsample): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(original_name=Conv2d)
#           (1): RecursiveScriptModule(original_name=BatchNorm2d)
#         )
#       )
#       (1): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (2): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#     )
#     (layer2): RecursiveScriptModule(
#       original_name=Sequential
#       (0): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#         (downsample): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(original_name=Conv2d)
#           (1): RecursiveScriptModule(original_name=BatchNorm2d)
#         )
#       )
#       (1): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (2): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (3): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#     )
#     (layer3): RecursiveScriptModule(
#       original_name=Sequential
#       (0): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#         (downsample): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(original_name=Conv2d)
#           (1): RecursiveScriptModule(original_name=BatchNorm2d)
#         )
#       )
#       (1): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (2): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (3): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (4): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (5): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#     )
#     (layer4): RecursiveScriptModule(
#       original_name=Sequential
#       (0): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#         (downsample): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(original_name=Conv2d)
#           (1): RecursiveScriptModule(original_name=BatchNorm2d)
#         )
#       )
#       (1): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (2): RecursiveScriptModule(
#         original_name=BottleneckV1b
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#     )
#     (avgpool): RecursiveScriptModule(original_name=AdaptiveAvgPool2d)
#     (fc): RecursiveScriptModule(original_name=Linear)
#   )
#   (head): RecursiveScriptModule(
#     original_name=_DeepLabHead
#     (aspp): RecursiveScriptModule(
#       original_name=_ASPP
#       (aspp0): RecursiveScriptModule(
#         original_name=Sequential
#         (conv): RecursiveScriptModule(original_name=Conv2d)
#         (bn): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (aspp1): RecursiveScriptModule(
#         original_name=SeparableConv2d
#         (block): RecursiveScriptModule(
#           original_name=Sequential
#           (depthwise): RecursiveScriptModule(original_name=Conv2d)
#           (bn_depth): RecursiveScriptModule(original_name=BatchNorm2d)
#           (relu1): RecursiveScriptModule(original_name=ReLU)
#           (pointwise): RecursiveScriptModule(original_name=Conv2d)
#           (bn_point): RecursiveScriptModule(original_name=BatchNorm2d)
#           (relu2): RecursiveScriptModule(original_name=ReLU)
#         )
#       )
#       (aspp2): RecursiveScriptModule(
#         original_name=SeparableConv2d
#         (block): RecursiveScriptModule(
#           original_name=Sequential
#           (depthwise): RecursiveScriptModule(original_name=Conv2d)
#           (bn_depth): RecursiveScriptModule(original_name=BatchNorm2d)
#           (relu1): RecursiveScriptModule(original_name=ReLU)
#           (pointwise): RecursiveScriptModule(original_name=Conv2d)
#           (bn_point): RecursiveScriptModule(original_name=BatchNorm2d)
#           (relu2): RecursiveScriptModule(original_name=ReLU)
#         )
#       )
#       (aspp3): RecursiveScriptModule(
#         original_name=SeparableConv2d
#         (block): RecursiveScriptModule(
#           original_name=Sequential
#           (depthwise): RecursiveScriptModule(original_name=Conv2d)
#           (bn_depth): RecursiveScriptModule(original_name=BatchNorm2d)
#           (relu1): RecursiveScriptModule(original_name=ReLU)
#           (pointwise): RecursiveScriptModule(original_name=Conv2d)
#           (bn_point): RecursiveScriptModule(original_name=BatchNorm2d)
#           (relu2): RecursiveScriptModule(original_name=ReLU)
#         )
#       )
#       (image_pooling): RecursiveScriptModule(
#         original_name=Sequential
#         (gap): RecursiveScriptModule(original_name=AdaptiveAvgPool2d)
#         (conv): RecursiveScriptModule(original_name=Conv2d)
#         (bn): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (conv): RecursiveScriptModule(original_name=Conv2d)
#       (bn): RecursiveScriptModule(original_name=BatchNorm2d)
#       (relu): RecursiveScriptModule(original_name=ReLU)
#       (dropout): RecursiveScriptModule(original_name=Dropout2d)
#     )
#     (c1_block): RecursiveScriptModule(
#       original_name=_ConvBNReLU
#       (conv): RecursiveScriptModule(original_name=Conv2d)
#       (bn): RecursiveScriptModule(original_name=BatchNorm2d)
#       (relu): RecursiveScriptModule(original_name=ReLU)
#     )
#     (block): RecursiveScriptModule(
#       original_name=Sequential
#       (0): RecursiveScriptModule(
#         original_name=SeparableConv2d
#         (block): RecursiveScriptModule(
#           original_name=Sequential
#           (depthwise): RecursiveScriptModule(original_name=Conv2d)
#           (bn_depth): RecursiveScriptModule(original_name=BatchNorm2d)
#           (relu1): RecursiveScriptModule(original_name=ReLU)
#           (pointwise): RecursiveScriptModule(original_name=Conv2d)
#           (bn_point): RecursiveScriptModule(original_name=BatchNorm2d)
#           (relu2): RecursiveScriptModule(original_name=ReLU)
#         )
#       )
#       (1): RecursiveScriptModule(
#         original_name=SeparableConv2d
#         (block): RecursiveScriptModule(
#           original_name=Sequential
#           (depthwise): RecursiveScriptModule(original_name=Conv2d)
#           (bn_depth): RecursiveScriptModule(original_name=BatchNorm2d)
#           (relu1): RecursiveScriptModule(original_name=ReLU)
#           (pointwise): RecursiveScriptModule(original_name=Conv2d)
#           (bn_point): RecursiveScriptModule(original_name=BatchNorm2d)
#           (relu2): RecursiveScriptModule(original_name=ReLU)
#         )
#       )
#       (2): RecursiveScriptModule(original_name=Conv2d)
#     )
#   )
# )

# %%
import torchvision.transforms as transforms
def transform_image(image):
    my_transforms = transforms.Compose([transforms.ToTensor(),
                                        transforms.Normalize(
                                            [0.485, 0.456, 0.406],
                                            [0.229, 0.224, 0.225])])
    image_aux = image
    return my_transforms(image_aux).unsqueeze(0).to(device)

# %%
image = Image.open('dataset/Images/test/color_154.jpg')

# %%
image = transforms.Resize((480,640))(image)
tensor = transform_image(image=image)

# %%
model.to(device)
with torch.no_grad():
    outputs = model(tensor)

outputs = torch.argmax(outputs,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-df8b25ef78d2> in <module>
# ----> 1 model.to(device)
#       2 with torch.no_grad():
#       3     outputs = model(tensor)
#       4
#       5 outputs = torch.argmax(outputs,1)
#
# NameError: name 'model' is not defined

# %%
mask = np.array(outputs.cpu())

# %%
mask[mask==4]=255
mask[mask==1]=150
mask[mask==3]=76
mask[mask==2]=29

# %%
mask=np.reshape(mask,(480,640))

# %%
maskShow = Image.fromarray(mask.astype('uint8'))
maskShow
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7FB71078F6D8>

# %%
maskrgb = maskShow.convert('RGB')
maskrgb = np.array(maskrgb)
maskrgb[(maskrgb==[150,150,150]).all(axis=2)]=[0,255,0]
maskrgb[(maskrgb==[76,76,76]).all(axis=2)]=[255,0,0]
maskrgb[(maskrgb==[29,29,29]).all(axis=2)]=[0,0,255]

# %%
maskRGBShow = Image.fromarray(maskrgb.astype('uint8'))
maskRGBShow
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FB7F908B860>

# %%
maskRGBShow.save('deeplab_pred_155.jpg')
